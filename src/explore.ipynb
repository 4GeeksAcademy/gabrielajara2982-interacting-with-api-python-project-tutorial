# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv


# load the .env file variables
load_dotenv()

# Get credential values
client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
spotify = spotipy.Spotify(auth_manager=auth_manager)

artist_id = "6HqPNOo6OV9rPbEY7MP9T8" #Julio Jaramillo - Pasillo Ecuatoriano

# Conseguir las canciones top del artista
results = spotify.artist_top_tracks(artist_id)

songs = []
for track in results['tracks']:
    songs.append({
        'name': track['name'],
        'popularity': track['popularity'],
        'duration_min': track['duration_ms'] / 60000
    })
print(songs)

# se hace DF
tracks_df = pd.DataFrame(songs)

print(tracks_df.head(11))

# Visualizacion de Datos, correlacion entre popularidad de una cancion y su duracion 

plt.scatter(tracks_df['duration_min'], tracks_df['popularity'])
plt.xlabel('Duracion en Minutos')
plt.ylabel('Popularidad')
plt.title('Relacion entre Duracion y Popularidad')
plt.show()
print ("Existe una correlacion entre popularidad de una canción y su duracion solo para ciertas canciones \n, en general no existe una correlacion fuerte entre las dos variables, \n siendo una coincidencia de la cancion entre su popularidad y duracion, por una moda cultural")
# Out:
# [{'name': 'Nuestro Juramento', 'popularity': 67, 'duration_min': 3.2662166666666668}, {'name': 'Ódiame', 'popularity': 63, 'duration_min': 2.8817666666666666}, {'name': 'Ayer y Hoy', 'popularity': 52, 'duration_min': 2.36495}, {'name': 'Reminiscencias', 'popularity': 61, 'duration_min': 2.24905}, {'name': 'Rondando Tu Esquina', 'popularity': 61, 'duration_min': 2.6404833333333335}, {'name': 'No Me Toquen Ese Vals', 'popularity': 59, 'duration_min': 2.5397666666666665}, {'name': 'Que Nadie Sepa Mi Sufrir', 'popularity': 52, 'duration_min': 2.740666666666667}, {'name': 'Te Esperaré', 'popularity': 56, 'duration_min': 2.5697666666666668}, {'name': 'Cinco Centavitos', 'popularity': 52, 'duration_min': 2.4524333333333335}, {'name': 'Fatalidad', 'popularity': 54, 'duration_min': 3.07}]
#                        name  popularity  duration_min
# 0         Nuestro Juramento          67      3.266217
# 1                    Ódiame          63      2.881767
# ...
